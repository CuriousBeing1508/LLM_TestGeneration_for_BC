# %%
import json
data = json.load(open("/Volumes/Rachna-HD/GPTResults/Exp7BatchResultsOp2/pre/compile_results_pre.json"))
bbc136 = data["compilation_results"].get("BBC136", {})
print("failed keys:", list(bbc136.get("failed", {}).keys())[:5])
print("compiled:", bbc136.get("compiled", [])[:3])
print("file_counts:", bbc136.get("file_counts", {}))
# Out:
# failed keys: ['BBC136U26Test.java', 'BBC136U27Test.java', 'BBC136U34Test.java', 'BBC136U33Test.java', 'BBC136U20Test.java']
# compiled: ['BBC136U37Test.java', 'BBC136U38Test.java', 'BBC136U23Test.java']
# file_counts: {'files_generated': 39, 'files_compiled': 9}
