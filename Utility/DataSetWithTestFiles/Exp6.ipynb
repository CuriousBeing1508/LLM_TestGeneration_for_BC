# %%
import json
import shutil
from pathlib import Path

# =============================================================================
# CONFIGURATION — only edit this section
# =============================================================================

# Folder containing BBC_instance/*.txt test files
TESTS_DIR = "/Volumes/Rachna-HD/FilteredDataset/Exp6LLMOutput/GPT4o"

# Full path to the compilation results JSON
JSON_PATH = "/Volumes/Rachna-HD/GPTResults/Exp6BatchResults/pre/compile_results_pre.json"

# Root folder where compiled_pre structure will be created
OUTPUT_DIR = "/Volumes/Rachna-HD/ResultsDataset/Exp6LLMOutput/GPT4o/compiled_pre"

# =============================================================================


def diagnose(tests_base, results):
    """
    Before copying, inspect every compiled file in the JSON and report:
    - exact path we looked for on disk
    - what .txt files actually exist in that BBC instance folder
    """
    print("\n" + "="*60)
    print("DIAGNOSTIC RUN — no files will be copied")
    print("="*60)

    total_in_json = 0
    total_found   = 0
    total_missing = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("compiled", [])
        if not compiled_files:
            continue

        src_instance_dir = tests_base / bbc_instance
        missing_in_instance = []

        for filename in compiled_files:
            total_in_json += 1
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                total_found += 1
            else:
                total_missing += 1
                missing_in_instance.append(stem)

        if missing_in_instance:
            print(f"\n[{bbc_instance}] {len(missing_in_instance)} missing:")
            for stem in missing_in_instance:
                print(f"  Looked for : {src_instance_dir / (stem + '_prompt.txt')}")

            # Show what .txt files actually exist in that folder
            actual_files = sorted(src_instance_dir.glob("*.txt")) if src_instance_dir.exists() else []
            if actual_files:
                print(f"  Actual .txt files in folder ({len(actual_files)}):")
                for f in actual_files:
                    print(f"    {f.name}")
            else:
                print(f"  Folder does not exist or has no .txt files: {src_instance_dir}")

    print("\n" + "="*60)
    print(f"Total in JSON  : {total_in_json}")
    print(f"Found on disk  : {total_found}")
    print(f"Missing        : {total_missing}")
    print("="*60 + "\n")


def organize_compiled_pre(run_diagnostic=False):
    tests_base  = Path(TESTS_DIR)
    json_path   = Path(JSON_PATH)
    output_base = Path(OUTPUT_DIR)

    if not json_path.exists():
        print(f"[ERROR] JSON file not found: {json_path}")
        return

    with open(json_path, "r") as f:
        data = json.load(f)

    results = data.get("compilation_results", {})
    if not results:
        print("[ERROR] 'compilation_results' key is empty or missing in JSON.")
        return

    if run_diagnostic:
        diagnose(tests_base, results)
        return

    copied_total  = 0
    missing_total = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("compiled", [])

        if not compiled_files:
            print(f"  {bbc_instance}: no compiled files, skipping.")
            continue

        src_instance_dir = tests_base / bbc_instance
        tgt_instance_dir = output_base / bbc_instance
        tgt_instance_dir.mkdir(parents=True, exist_ok=True)

        copied  = 0
        missing = 0
        for filename in compiled_files:
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"
            tgt_file = tgt_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                shutil.copy2(src_file, tgt_file)
                copied += 1
            else:
                print(f"    [MISSING] {src_file}")
                missing += 1

        print(f"  {bbc_instance}: copied {copied} file(s)"
              + (f", {missing} missing" if missing else ""))
        copied_total  += copied
        missing_total += missing

    print(f"\nDone. Total copied: {copied_total}, Total missing: {missing_total}")


if __name__ == "__main__":
    # Set to True to inspect mismatches before copying
    organize_compiled_pre(run_diagnostic=False)
# Out:
#   BBC01: no compiled files, skipping.
#   BBC02: no compiled files, skipping.
#   BBC03: no compiled files, skipping.
#   BBC04: copied 2 file(s)
#   BBC05: no compiled files, skipping.
#   BBC06: copied 78 file(s)
#   BBC07: copied 2 file(s)
#   BBC10: no compiled files, skipping.
#   BBC16: no compiled files, skipping.
#   BBC17: copied 77 file(s)
#   BBC22: no compiled files, skipping.
#   BBC24: no compiled files, skipping.
#   BBC26: copied 2 file(s)
#   BBC27: copied 95 file(s)
#   BBC31: no compiled files, skipping.
#   BBC33: copied 58 file(s)
#   BBC35: no compiled files, skipping.
#   BBC36: copied 72 file(s)
#   BBC41: copied 1 file(s)
#   BBC42: copied 2 file(s)
#   BBC44: no compiled files, skipping.
#   BBC45: copied 9 file(s)
#   BBC48: copied 1 file(s)
#   BBC49: copied 66 file(s)
#   BBC50: no compiled files, skipping.
#   BBC51: no compiled files, skipping.
#   BBC52: no compiled files, skipping.
#   BBC53: no compiled files, skipping.
#   BBC54: copied 60 file(s)
#   BBC55: no compiled files, skipping.
#   BBC56: copied 61 file(s)
#   BBC59: no compiled files, skipping.
#   BBC60: no compiled files, skipping.
#   BBC63: copied 11 file(s)
#   BBC64: no compiled files, skipping.
#   BBC66: copied 1 file(s)
#   BBC70: no compiled files, skipping.
#   BBC72: copied 272 file(s)
#   BBC73: copied 275 file(s)
#   BBC74: no compiled files, skipping.
#   BBC78: no compiled files, skipping.
#   BBC79: no compiled files, skipping.
#   BBC80: no compiled files, skipping.
#   BBC81: no compiled files, skipping.
#   BBC82: no compiled files, skipping.
#   BBC83: no compiled files, skipping.
#   BBC88: no compiled files, skipping.
#   BBC94: no compiled files, skipping.
#   BBC97: no compiled files, skipping.
#   BBC98: copied 1 file(s)
#   BBC99: no compiled files, skipping.
#   BBC101: copied 126 file(s)
#   BBC103: copied 9 file(s)
#   BBC104: no compiled files, skipping.
#   BBC106: copied 2 file(s)
#   BBC107: no compiled files, skipping.
#   BBC111: no compiled files, skipping.
#   BBC115: copied 15 file(s)
#   BBC118: no compiled files, skipping.
#   BBC119: no compiled files, skipping.
#   BBC121: no compiled files, skipping.
#   BBC123: copied 2 file(s)
#   BBC124: no compiled files, skipping.
#   BBC131: copied 10 file(s)
#   BBC132: copied 69 file(s)
#   BBC135: copied 1 file(s)
#   BBC136: copied 10 file(s)
#   BBC137: no compiled files, skipping.
#   BBC143: no compiled files, skipping.
#   BBC144: no compiled files, skipping.
#   BBC145: copied 2 file(s)
#   BBC146: copied 98 file(s)
#   BBC147: copied 58 file(s)
#   BBC148: copied 1 file(s)
#   BBC150: copied 21 file(s)
#   BBC153: no compiled files, skipping.
#   BBC155: no compiled files, skipping.
#   BBC158: no compiled files, skipping.
#   BBC162: copied 10 file(s)
#   BBC165: copied 74 file(s)
#   BBC167: copied 13 file(s)
#   BBC168: no compiled files, skipping.
#   BBC170: no compiled files, skipping.
#   BBC178: copied 1 file(s)
#   BBC179: no compiled files, skipping.
#   BBC182: no compiled files, skipping.
#   BBC184: no compiled files, skipping.
#   BBC186: no compiled files, skipping.
#   BBC187: copied 1 file(s)
#
# Done. Total copied: 1669, Total missing: 0

# %%
import json
import shutil
from pathlib import Path

# =============================================================================
# CONFIGURATION — only edit this section
# =============================================================================

# Folder containing BBC_instance/*.txt test files
TESTS_DIR = "/Volumes/Rachna-HD/FilteredDataset/Exp6LLMOutput/Qwen3_480b_cloud"

# Full path to the compilation results JSON
JSON_PATH = "/Volumes/Rachna-HD/Qwen480Results/Exp6BatchResults/pre/compile_results_pre.json"

# Root folder where compiled_pre structure will be created
OUTPUT_DIR = "/Volumes/Rachna-HD/ResultsDataset/Exp6LLMOutput/Qwen_480b_cloud/compiled_pre"

# =============================================================================


def diagnose(tests_base, results):
    """
    Before copying, inspect every compiled file in the JSON and report:
    - exact path we looked for on disk
    - what .txt files actually exist in that BBC instance folder
    """
    print("\n" + "="*60)
    print("DIAGNOSTIC RUN — no files will be copied")
    print("="*60)

    total_in_json = 0
    total_found   = 0
    total_missing = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("compiled", [])
        if not compiled_files:
            continue

        src_instance_dir = tests_base / bbc_instance
        missing_in_instance = []

        for filename in compiled_files:
            total_in_json += 1
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                total_found += 1
            else:
                total_missing += 1
                missing_in_instance.append(stem)

        if missing_in_instance:
            print(f"\n[{bbc_instance}] {len(missing_in_instance)} missing:")
            for stem in missing_in_instance:
                print(f"  Looked for : {src_instance_dir / (stem + '_prompt.txt')}")

            # Show what .txt files actually exist in that folder
            actual_files = sorted(src_instance_dir.glob("*.txt")) if src_instance_dir.exists() else []
            if actual_files:
                print(f"  Actual .txt files in folder ({len(actual_files)}):")
                for f in actual_files:
                    print(f"    {f.name}")
            else:
                print(f"  Folder does not exist or has no .txt files: {src_instance_dir}")

    print("\n" + "="*60)
    print(f"Total in JSON  : {total_in_json}")
    print(f"Found on disk  : {total_found}")
    print(f"Missing        : {total_missing}")
    print("="*60 + "\n")


def organize_compiled_pre(run_diagnostic=False):
    tests_base  = Path(TESTS_DIR)
    json_path   = Path(JSON_PATH)
    output_base = Path(OUTPUT_DIR)

    if not json_path.exists():
        print(f"[ERROR] JSON file not found: {json_path}")
        return

    with open(json_path, "r") as f:
        data = json.load(f)

    results = data.get("compilation_results", {})
    if not results:
        print("[ERROR] 'compilation_results' key is empty or missing in JSON.")
        return

    if run_diagnostic:
        diagnose(tests_base, results)
        return

    copied_total  = 0
    missing_total = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("compiled", [])

        if not compiled_files:
            print(f"  {bbc_instance}: no compiled files, skipping.")
            continue

        src_instance_dir = tests_base / bbc_instance
        tgt_instance_dir = output_base / bbc_instance
        tgt_instance_dir.mkdir(parents=True, exist_ok=True)

        copied  = 0
        missing = 0
        for filename in compiled_files:
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"
            tgt_file = tgt_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                shutil.copy2(src_file, tgt_file)
                copied += 1
            else:
                print(f"    [MISSING] {src_file}")
                missing += 1

        print(f"  {bbc_instance}: copied {copied} file(s)"
              + (f", {missing} missing" if missing else ""))
        copied_total  += copied
        missing_total += missing

    print(f"\nDone. Total copied: {copied_total}, Total missing: {missing_total}")


if __name__ == "__main__":
    # Set to True to inspect mismatches before copying
    organize_compiled_pre(run_diagnostic=False)
# Out:
#   BBC01: no compiled files, skipping.
#   BBC02: no compiled files, skipping.
#   BBC03: no compiled files, skipping.
#   BBC04: copied 31 file(s)
#   BBC05: no compiled files, skipping.
#   BBC06: copied 134 file(s)
#   BBC07: copied 6 file(s)
#   BBC10: no compiled files, skipping.
#   BBC16: no compiled files, skipping.
#   BBC17: copied 128 file(s)
#   BBC22: no compiled files, skipping.
#   BBC24: no compiled files, skipping.
#   BBC26: copied 1 file(s)
#   BBC27: copied 31 file(s)
#   BBC31: no compiled files, skipping.
#   BBC33: copied 61 file(s)
#   BBC35: no compiled files, skipping.
#   BBC36: copied 124 file(s)
#   BBC41: copied 6 file(s)
#   BBC42: copied 2 file(s)
#   BBC44: no compiled files, skipping.
#   BBC45: copied 6 file(s)
#   BBC48: copied 1 file(s)
#   BBC49: copied 137 file(s)
#   BBC50: no compiled files, skipping.
#   BBC51: no compiled files, skipping.
#   BBC52: no compiled files, skipping.
#   BBC53: no compiled files, skipping.
#   BBC54: copied 61 file(s)
#   BBC55: no compiled files, skipping.
#   BBC56: copied 61 file(s)
#   BBC59: no compiled files, skipping.
#   BBC60: no compiled files, skipping.
#   BBC63: copied 7 file(s)
#   BBC64: no compiled files, skipping.
#   BBC66: no compiled files, skipping.
#   BBC70: no compiled files, skipping.
#   BBC72: copied 215 file(s)
#   BBC73: copied 233 file(s)
#   BBC74: no compiled files, skipping.
#   BBC78: no compiled files, skipping.
#   BBC79: no compiled files, skipping.
#   BBC80: no compiled files, skipping.
#   BBC81: no compiled files, skipping.
#   BBC82: no compiled files, skipping.
#   BBC83: no compiled files, skipping.
#   BBC88: no compiled files, skipping.
#   BBC94: no compiled files, skipping.
#   BBC97: copied 3 file(s)
#   BBC98: no compiled files, skipping.
#   BBC99: no compiled files, skipping.
#   BBC101: copied 120 file(s)
#   BBC103: copied 10 file(s)
#   BBC104: no compiled files, skipping.
#   BBC106: copied 2 file(s)
#   BBC107: no compiled files, skipping.
#   BBC111: no compiled files, skipping.
#   BBC115: copied 7 file(s)
#   BBC118: no compiled files, skipping.
#   BBC119: no compiled files, skipping.
#   BBC121: no compiled files, skipping.
#   BBC123: copied 1 file(s)
#   BBC124: no compiled files, skipping.
#   BBC131: copied 7 file(s)
#   BBC132: copied 134 file(s)
#   BBC135: copied 1 file(s)
#   BBC136: copied 8 file(s)
#   BBC137: no compiled files, skipping.
#   BBC143: no compiled files, skipping.
#   BBC144: no compiled files, skipping.
#   BBC145: copied 2 file(s)
#   BBC146: copied 29 file(s)
#   BBC147: copied 64 file(s)
#   BBC148: copied 8 file(s)
#   BBC150: copied 14 file(s)
#   BBC153: no compiled files, skipping.
#   BBC155: no compiled files, skipping.
#   BBC158: no compiled files, skipping.
#   BBC162: copied 7 file(s)
#   BBC165: copied 131 file(s)
#   BBC167: copied 8 file(s)
#   BBC168: no compiled files, skipping.
#   BBC170: no compiled files, skipping.
#   BBC178: copied 1 file(s)
#   BBC179: no compiled files, skipping.
#   BBC182: no compiled files, skipping.
#   BBC184: no compiled files, skipping.
#   BBC186: no compiled files, skipping.
#   BBC187: no compiled files, skipping.
#
# Done. Total copied: 1802, Total missing: 0

# %%
Execution Dataset

# %%
import json
import shutil
from pathlib import Path

# =============================================================================
# CONFIGURATION — only edit this section
# =============================================================================

# Folder containing BBC_instance/*.txt test files
TESTS_DIR = "/Volumes/Rachna-HD/FilteredDataset/Exp6LLMOutput/GPT4o"

# Full path to the compilation results JSON
JSON_PATH = "/Volumes/Rachna-HD/GPTResults/Exp6BatchResults/pre/execute_results_pre.json"

# Root folder where compiled_pre structure will be created
OUTPUT_DIR = "/Volumes/Rachna-HD/ResultsDataset/Exp6LLMOutput/GPT4o/execution_pre"

# =============================================================================


def diagnose(tests_base, results):
    """
    Before copying, inspect every compiled file in the JSON and report:
    - exact path we looked for on disk
    - what .txt files actually exist in that BBC instance folder
    """
    print("\n" + "="*60)
    print("DIAGNOSTIC RUN — no files will be copied")
    print("="*60)

    total_in_json = 0
    total_found   = 0
    total_missing = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("passed", [])
        if not compiled_files:
            continue

        src_instance_dir = tests_base / bbc_instance
        missing_in_instance = []

        for filename in compiled_files:
            total_in_json += 1
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                total_found += 1
            else:
                total_missing += 1
                missing_in_instance.append(stem)

        if missing_in_instance:
            print(f"\n[{bbc_instance}] {len(missing_in_instance)} missing:")
            for stem in missing_in_instance:
                print(f"  Looked for : {src_instance_dir / (stem + '_prompt.txt')}")

            # Show what .txt files actually exist in that folder
            actual_files = sorted(src_instance_dir.glob("*.txt")) if src_instance_dir.exists() else []
            if actual_files:
                print(f"  Actual .txt files in folder ({len(actual_files)}):")
                for f in actual_files:
                    print(f"    {f.name}")
            else:
                print(f"  Folder does not exist or has no .txt files: {src_instance_dir}")

    print("\n" + "="*60)
    print(f"Total in JSON  : {total_in_json}")
    print(f"Found on disk  : {total_found}")
    print(f"Missing        : {total_missing}")
    print("="*60 + "\n")


def organize_compiled_pre(run_diagnostic=False):
    tests_base  = Path(TESTS_DIR)
    json_path   = Path(JSON_PATH)
    output_base = Path(OUTPUT_DIR)

    if not json_path.exists():
        print(f"[ERROR] JSON file not found: {json_path}")
        return

    with open(json_path, "r") as f:
        data = json.load(f)

    results = data.get("execution_results", {})
    if not results:
        print("[ERROR] 'execution_results' key is empty or missing in JSON.")
        return

    if run_diagnostic:
        diagnose(tests_base, results)
        return

    copied_total  = 0
    missing_total = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("passed", [])

        if not compiled_files:
            print(f"  {bbc_instance}: no execution files, skipping.")
            continue

        src_instance_dir = tests_base / bbc_instance
        tgt_instance_dir = output_base / bbc_instance
        tgt_instance_dir.mkdir(parents=True, exist_ok=True)

        copied  = 0
        missing = 0
        for filename in compiled_files:
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"
            tgt_file = tgt_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                shutil.copy2(src_file, tgt_file)
                copied += 1
            else:
                print(f"    [MISSING] {src_file}")
                missing += 1

        print(f"  {bbc_instance}: copied {copied} file(s)"
              + (f", {missing} missing" if missing else ""))
        copied_total  += copied
        missing_total += missing

    print(f"\nDone. Total copied: {copied_total}, Total missing: {missing_total}")


if __name__ == "__main__":
    # Set to True to inspect mismatches before copying
    organize_compiled_pre(run_diagnostic=False)
# Out:
#   BBC04: no execution files, skipping.
#   BBC06: copied 24 file(s)
#   BBC07: copied 2 file(s)
#   BBC17: copied 24 file(s)
#   BBC26: copied 1 file(s)
#   BBC27: copied 83 file(s)
#   BBC33: copied 54 file(s)
#   BBC36: copied 25 file(s)
#   BBC41: no execution files, skipping.
#   BBC42: copied 1 file(s)
#   BBC45: copied 6 file(s)
#   BBC48: copied 1 file(s)
#   BBC49: copied 25 file(s)
#   BBC54: copied 54 file(s)
#   BBC56: copied 52 file(s)
#   BBC63: copied 7 file(s)
#   BBC66: copied 1 file(s)
#   BBC72: copied 80 file(s)
#   BBC73: copied 82 file(s)
#   BBC98: copied 1 file(s)
#   BBC101: copied 68 file(s)
#   BBC103: copied 5 file(s)
#   BBC106: copied 1 file(s)
#   BBC115: copied 8 file(s)
#   BBC123: no execution files, skipping.
#   BBC131: copied 4 file(s)
#   BBC132: copied 23 file(s)
#   BBC135: copied 1 file(s)
#   BBC136: copied 7 file(s)
#   BBC145: copied 2 file(s)
#   BBC146: copied 86 file(s)
#   BBC147: copied 53 file(s)
#   BBC148: no execution files, skipping.
#   BBC150: copied 5 file(s)
#   BBC162: copied 7 file(s)
#   BBC165: copied 28 file(s)
#   BBC167: copied 8 file(s)
#   BBC178: copied 1 file(s)
#   BBC187: copied 1 file(s)
#
# Done. Total copied: 831, Total missing: 0

# %%
import json
import shutil
from pathlib import Path

# =============================================================================
# CONFIGURATION — only edit this section
# =============================================================================

# Folder containing BBC_instance/*.txt test files
TESTS_DIR = "/Volumes/Rachna-HD/FilteredDataset/Exp6LLMOutput/Qwen3_480b_cloud"

# Full path to the compilation results JSON
JSON_PATH = "/Volumes/Rachna-HD/Qwen480Results/Exp6BatchResults/pre/execute_results_pre.json"

# Root folder where compiled_pre structure will be created
OUTPUT_DIR = "/Volumes/Rachna-HD/ResultsDataset/Exp6LLMOutput/Qwen3_480b_cloud/execution_pre"

# =============================================================================


def diagnose(tests_base, results):
    """
    Before copying, inspect every compiled file in the JSON and report:
    - exact path we looked for on disk
    - what .txt files actually exist in that BBC instance folder
    """
    print("\n" + "="*60)
    print("DIAGNOSTIC RUN — no files will be copied")
    print("="*60)

    total_in_json = 0
    total_found   = 0
    total_missing = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("passed", [])
        if not compiled_files:
            continue

        src_instance_dir = tests_base / bbc_instance
        missing_in_instance = []

        for filename in compiled_files:
            total_in_json += 1
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                total_found += 1
            else:
                total_missing += 1
                missing_in_instance.append(stem)

        if missing_in_instance:
            print(f"\n[{bbc_instance}] {len(missing_in_instance)} missing:")
            for stem in missing_in_instance:
                print(f"  Looked for : {src_instance_dir / (stem + '_prompt.txt')}")

            # Show what .txt files actually exist in that folder
            actual_files = sorted(src_instance_dir.glob("*.txt")) if src_instance_dir.exists() else []
            if actual_files:
                print(f"  Actual .txt files in folder ({len(actual_files)}):")
                for f in actual_files:
                    print(f"    {f.name}")
            else:
                print(f"  Folder does not exist or has no .txt files: {src_instance_dir}")

    print("\n" + "="*60)
    print(f"Total in JSON  : {total_in_json}")
    print(f"Found on disk  : {total_found}")
    print(f"Missing        : {total_missing}")
    print("="*60 + "\n")


def organize_compiled_pre(run_diagnostic=False):
    tests_base  = Path(TESTS_DIR)
    json_path   = Path(JSON_PATH)
    output_base = Path(OUTPUT_DIR)

    if not json_path.exists():
        print(f"[ERROR] JSON file not found: {json_path}")
        return

    with open(json_path, "r") as f:
        data = json.load(f)

    results = data.get("execution_results", {})
    if not results:
        print("[ERROR] 'execution_results' key is empty or missing in JSON.")
        return

    if run_diagnostic:
        diagnose(tests_base, results)
        return

    copied_total  = 0
    missing_total = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("passed", [])

        if not compiled_files:
            print(f"  {bbc_instance}: no execution files, skipping.")
            continue

        src_instance_dir = tests_base / bbc_instance
        tgt_instance_dir = output_base / bbc_instance
        tgt_instance_dir.mkdir(parents=True, exist_ok=True)

        copied  = 0
        missing = 0
        for filename in compiled_files:
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"
            tgt_file = tgt_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                shutil.copy2(src_file, tgt_file)
                copied += 1
            else:
                print(f"    [MISSING] {src_file}")
                missing += 1

        print(f"  {bbc_instance}: copied {copied} file(s)"
              + (f", {missing} missing" if missing else ""))
        copied_total  += copied
        missing_total += missing

    print(f"\nDone. Total copied: {copied_total}, Total missing: {missing_total}")


if __name__ == "__main__":
    # Set to True to inspect mismatches before copying
    organize_compiled_pre(run_diagnostic=False)
# Out:
#   BBC04: copied 22 file(s)
#   BBC06: copied 78 file(s)
#   BBC07: copied 6 file(s)
#   BBC17: copied 91 file(s)
#   BBC26: copied 1 file(s)
#   BBC27: copied 19 file(s)
#   BBC33: copied 49 file(s)
#   BBC36: copied 84 file(s)
#   BBC41: copied 4 file(s)
#   BBC42: no execution files, skipping.
#   BBC45: copied 2 file(s)
#   BBC48: copied 1 file(s)
#   BBC49: copied 92 file(s)
#   BBC54: copied 44 file(s)
#   BBC56: copied 48 file(s)
#   BBC63: copied 4 file(s)
#   BBC72: copied 70 file(s)
#   BBC73: copied 72 file(s)
#   BBC97: copied 2 file(s)
#   BBC101: copied 63 file(s)
#   BBC103: copied 3 file(s)
#   BBC106: copied 2 file(s)
#   BBC115: copied 3 file(s)
#   BBC123: no execution files, skipping.
#   BBC131: copied 2 file(s)
#   BBC132: copied 87 file(s)
#   BBC135: copied 1 file(s)
#   BBC136: copied 5 file(s)
#   BBC145: copied 2 file(s)
#   BBC146: copied 21 file(s)
#   BBC147: copied 51 file(s)
#   BBC148: copied 5 file(s)
#   BBC150: copied 4 file(s)
#   BBC162: copied 5 file(s)
#   BBC165: copied 81 file(s)
#   BBC167: copied 4 file(s)
#   BBC178: no execution files, skipping.
#
# Done. Total copied: 1028, Total missing: 0
