# %%
import json
import shutil
from pathlib import Path

# =============================================================================
# CONFIGURATION — only edit this section
# =============================================================================

# Folder containing BBC_instance/*.txt test files
TESTS_DIR = "/Volumes/Rachna-HD/FilteredDataset/Exp7LLMOutput/GPT4o"

# Full path to the compilation results JSON
JSON_PATH = "/Volumes/Rachna-HD/GPTResults/Exp7BatchResultsOp2/pre/compile_results_pre.json"

# Root folder where compiled_pre structure will be created
OUTPUT_DIR = "/Volumes/Rachna-HD/ResultsDataset/Exp7LLMOutput/GPT4o/compiled_pre"

# =============================================================================


def diagnose(tests_base, results):
    """
    Before copying, inspect every compiled file in the JSON and report:
    - exact path we looked for on disk
    - what .txt files actually exist in that BBC instance folder
    """
    print("\n" + "="*60)
    print("DIAGNOSTIC RUN — no files will be copied")
    print("="*60)

    total_in_json = 0
    total_found   = 0
    total_missing = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("compiled", [])
        if not compiled_files:
            continue

        src_instance_dir = tests_base / bbc_instance
        missing_in_instance = []

        for filename in compiled_files:
            total_in_json += 1
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                total_found += 1
            else:
                total_missing += 1
                missing_in_instance.append(stem)

        if missing_in_instance:
            print(f"\n[{bbc_instance}] {len(missing_in_instance)} missing:")
            for stem in missing_in_instance:
                print(f"  Looked for : {src_instance_dir / (stem + '_prompt.txt')}")

            # Show what .txt files actually exist in that folder
            actual_files = sorted(src_instance_dir.glob("*.txt")) if src_instance_dir.exists() else []
            if actual_files:
                print(f"  Actual .txt files in folder ({len(actual_files)}):")
                for f in actual_files:
                    print(f"    {f.name}")
            else:
                print(f"  Folder does not exist or has no .txt files: {src_instance_dir}")

    print("\n" + "="*60)
    print(f"Total in JSON  : {total_in_json}")
    print(f"Found on disk  : {total_found}")
    print(f"Missing        : {total_missing}")
    print("="*60 + "\n")


def organize_compiled_pre(run_diagnostic=False):
    tests_base  = Path(TESTS_DIR)
    json_path   = Path(JSON_PATH)
    output_base = Path(OUTPUT_DIR)

    if not json_path.exists():
        print(f"[ERROR] JSON file not found: {json_path}")
        return

    with open(json_path, "r") as f:
        data = json.load(f)

    results = data.get("compilation_results", {})
    if not results:
        print("[ERROR] 'compilation_results' key is empty or missing in JSON.")
        return

    if run_diagnostic:
        diagnose(tests_base, results)
        return

    copied_total  = 0
    missing_total = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("compiled", [])

        if not compiled_files:
            print(f"  {bbc_instance}: no compiled files, skipping.")
            continue

        src_instance_dir = tests_base / bbc_instance
        tgt_instance_dir = output_base / bbc_instance
        tgt_instance_dir.mkdir(parents=True, exist_ok=True)

        copied  = 0
        missing = 0
        for filename in compiled_files:
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"
            tgt_file = tgt_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                shutil.copy2(src_file, tgt_file)
                copied += 1
            else:
                print(f"    [MISSING] {src_file}")
                missing += 1

        print(f"  {bbc_instance}: copied {copied} file(s)"
              + (f", {missing} missing" if missing else ""))
        copied_total  += copied
        missing_total += missing

    print(f"\nDone. Total copied: {copied_total}, Total missing: {missing_total}")


if __name__ == "__main__":
    # Set to True to inspect mismatches before copying
    organize_compiled_pre(run_diagnostic=False)
# Out:
#   BBC01: no compiled files, skipping.
#   BBC02: no compiled files, skipping.
#   BBC03: copied 1 file(s)
#   BBC04: copied 1 file(s)
#   BBC05: no compiled files, skipping.
#   BBC06: copied 49 file(s)
#   BBC07: copied 2 file(s)
#   BBC10: no compiled files, skipping.
#   BBC16: no compiled files, skipping.
#   BBC17: copied 40 file(s)
#   BBC22: no compiled files, skipping.
#   BBC24: no compiled files, skipping.
#   BBC26: copied 1 file(s)
#   BBC27: copied 177 file(s)
#   BBC31: no compiled files, skipping.
#   BBC33: copied 55 file(s)
#   BBC35: no compiled files, skipping.
#   BBC36: copied 45 file(s)
#   BBC41: no compiled files, skipping.
#   BBC42: copied 2 file(s)
#   BBC44: no compiled files, skipping.
#   BBC45: copied 9 file(s)
#   BBC48: no compiled files, skipping.
#   BBC49: copied 46 file(s)
#   BBC50: copied 1 file(s)
#   BBC51: no compiled files, skipping.
#   BBC52: no compiled files, skipping.
#   BBC53: no compiled files, skipping.
#   BBC54: copied 55 file(s)
# ...

# %%
import json
import shutil
from pathlib import Path

# =============================================================================
# CONFIGURATION — only edit this section
# =============================================================================

# Folder containing BBC_instance/*.txt test files
TESTS_DIR = "/Volumes/Rachna-HD/FilteredDataset/Exp7LLMOutput/Qwen3_480b_cloud"

# Full path to the compilation results JSON
JSON_PATH = "/Volumes/Rachna-HD/Qwen480Results/Exp7BatchResults/pre/compile_results_pre.json"

# Root folder where compiled_pre structure will be created
OUTPUT_DIR = "/Volumes/Rachna-HD/ResultsDataset/Exp7LLMOutput/Qwen_480b_cloud/compiled_pre"

# =============================================================================


def diagnose(tests_base, results):
    """
    Before copying, inspect every compiled file in the JSON and report:
    - exact path we looked for on disk
    - what .txt files actually exist in that BBC instance folder
    """
    print("\n" + "="*60)
    print("DIAGNOSTIC RUN — no files will be copied")
    print("="*60)

    total_in_json = 0
    total_found   = 0
    total_missing = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("compiled", [])
        if not compiled_files:
            continue

        src_instance_dir = tests_base / bbc_instance
        missing_in_instance = []

        for filename in compiled_files:
            total_in_json += 1
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                total_found += 1
            else:
                total_missing += 1
                missing_in_instance.append(stem)

        if missing_in_instance:
            print(f"\n[{bbc_instance}] {len(missing_in_instance)} missing:")
            for stem in missing_in_instance:
                print(f"  Looked for : {src_instance_dir / (stem + '_prompt.txt')}")

            # Show what .txt files actually exist in that folder
            actual_files = sorted(src_instance_dir.glob("*.txt")) if src_instance_dir.exists() else []
            if actual_files:
                print(f"  Actual .txt files in folder ({len(actual_files)}):")
                for f in actual_files:
                    print(f"    {f.name}")
            else:
                print(f"  Folder does not exist or has no .txt files: {src_instance_dir}")

    print("\n" + "="*60)
    print(f"Total in JSON  : {total_in_json}")
    print(f"Found on disk  : {total_found}")
    print(f"Missing        : {total_missing}")
    print("="*60 + "\n")


def organize_compiled_pre(run_diagnostic=False):
    tests_base  = Path(TESTS_DIR)
    json_path   = Path(JSON_PATH)
    output_base = Path(OUTPUT_DIR)

    if not json_path.exists():
        print(f"[ERROR] JSON file not found: {json_path}")
        return

    with open(json_path, "r") as f:
        data = json.load(f)

    results = data.get("compilation_results", {})
    if not results:
        print("[ERROR] 'compilation_results' key is empty or missing in JSON.")
        return

    if run_diagnostic:
        diagnose(tests_base, results)
        return

    copied_total  = 0
    missing_total = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("compiled", [])

        if not compiled_files:
            print(f"  {bbc_instance}: no compiled files, skipping.")
            continue

        src_instance_dir = tests_base / bbc_instance
        tgt_instance_dir = output_base / bbc_instance
        tgt_instance_dir.mkdir(parents=True, exist_ok=True)

        copied  = 0
        missing = 0
        for filename in compiled_files:
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"
            tgt_file = tgt_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                shutil.copy2(src_file, tgt_file)
                copied += 1
            else:
                print(f"    [MISSING] {src_file}")
                missing += 1

        print(f"  {bbc_instance}: copied {copied} file(s)"
              + (f", {missing} missing" if missing else ""))
        copied_total  += copied
        missing_total += missing

    print(f"\nDone. Total copied: {copied_total}, Total missing: {missing_total}")


if __name__ == "__main__":
    # Set to True to inspect mismatches before copying
    organize_compiled_pre(run_diagnostic=False)
# Out:
#   BBC01: no compiled files, skipping.
#   BBC02: copied 1 file(s)
#   BBC03: copied 1 file(s)
#   BBC04: copied 12 file(s)
#   BBC05: no compiled files, skipping.
#   BBC06: copied 146 file(s)
#   BBC07: copied 2 file(s)
#   BBC10: no compiled files, skipping.
#   BBC16: no compiled files, skipping.
#   BBC17: copied 149 file(s)
#   BBC22: no compiled files, skipping.
#   BBC24: no compiled files, skipping.
#   BBC26: copied 1 file(s)
#   BBC27: copied 68 file(s)
#   BBC31: no compiled files, skipping.
#   BBC33: copied 63 file(s)
#   BBC35: no compiled files, skipping.
#   BBC36: copied 135 file(s)
#   BBC41: no compiled files, skipping.
#   BBC42: copied 6 file(s)
#   BBC44: no compiled files, skipping.
#   BBC45: copied 7 file(s)
#   BBC48: no compiled files, skipping.
#   BBC49: copied 145 file(s)
#   BBC50: copied 1 file(s)
#   BBC51: no compiled files, skipping.
#   BBC52: no compiled files, skipping.
#   BBC53: no compiled files, skipping.
#   BBC54: copied 69 file(s)
# ...

# %%
import json
import shutil
from pathlib import Path

# =============================================================================
# CONFIGURATION — only edit this section
# =============================================================================

# Folder containing BBC_instance/*.txt test files
TESTS_DIR = "/Volumes/Rachna-HD/FilteredDataset/Exp7LLMOutput/GPT_OSS_120b"

# Full path to the compilation results JSON
JSON_PATH = "/Volumes/Rachna-HD/GPTOSSResults/Exp7BatchResults/pre/compile_results_pre.json"

# Root folder where compiled_pre structure will be created
OUTPUT_DIR = "/Volumes/Rachna-HD/ResultsDataset/Exp7LLMOutput/GPT_OSS_120b/compiled_pre"

# =============================================================================


def diagnose(tests_base, results):
    """
    Before copying, inspect every compiled file in the JSON and report:
    - exact path we looked for on disk
    - what .txt files actually exist in that BBC instance folder
    """
    print("\n" + "="*60)
    print("DIAGNOSTIC RUN — no files will be copied")
    print("="*60)

    total_in_json = 0
    total_found   = 0
    total_missing = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("compiled", [])
        if not compiled_files:
            continue

        src_instance_dir = tests_base / bbc_instance
        missing_in_instance = []

        for filename in compiled_files:
            total_in_json += 1
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                total_found += 1
            else:
                total_missing += 1
                missing_in_instance.append(stem)

        if missing_in_instance:
            print(f"\n[{bbc_instance}] {len(missing_in_instance)} missing:")
            for stem in missing_in_instance:
                print(f"  Looked for : {src_instance_dir / (stem + '_prompt.txt')}")

            # Show what .txt files actually exist in that folder
            actual_files = sorted(src_instance_dir.glob("*.txt")) if src_instance_dir.exists() else []
            if actual_files:
                print(f"  Actual .txt files in folder ({len(actual_files)}):")
                for f in actual_files:
                    print(f"    {f.name}")
            else:
                print(f"  Folder does not exist or has no .txt files: {src_instance_dir}")

    print("\n" + "="*60)
    print(f"Total in JSON  : {total_in_json}")
    print(f"Found on disk  : {total_found}")
    print(f"Missing        : {total_missing}")
    print("="*60 + "\n")


def organize_compiled_pre(run_diagnostic=False):
    tests_base  = Path(TESTS_DIR)
    json_path   = Path(JSON_PATH)
    output_base = Path(OUTPUT_DIR)

    if not json_path.exists():
        print(f"[ERROR] JSON file not found: {json_path}")
        return

    with open(json_path, "r") as f:
        data = json.load(f)

    results = data.get("compilation_results", {})
    if not results:
        print("[ERROR] 'compilation_results' key is empty or missing in JSON.")
        return

    if run_diagnostic:
        diagnose(tests_base, results)
        return

    copied_total  = 0
    missing_total = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("compiled", [])

        if not compiled_files:
            print(f"  {bbc_instance}: no compiled files, skipping.")
            continue

        src_instance_dir = tests_base / bbc_instance
        tgt_instance_dir = output_base / bbc_instance
        tgt_instance_dir.mkdir(parents=True, exist_ok=True)

        copied  = 0
        missing = 0
        for filename in compiled_files:
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"
            tgt_file = tgt_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                shutil.copy2(src_file, tgt_file)
                copied += 1
            else:
                print(f"    [MISSING] {src_file}")
                missing += 1

        print(f"  {bbc_instance}: copied {copied} file(s)"
              + (f", {missing} missing" if missing else ""))
        copied_total  += copied
        missing_total += missing

    print(f"\nDone. Total copied: {copied_total}, Total missing: {missing_total}")


if __name__ == "__main__":
    # Set to True to inspect mismatches before copying
    organize_compiled_pre(run_diagnostic=False)
# Out:
#   BBC01: no compiled files, skipping.
#   BBC02: no compiled files, skipping.
#   BBC03: no compiled files, skipping.
#   BBC04: copied 3 file(s)
#   BBC05: no compiled files, skipping.
#   BBC06: copied 12 file(s)
#   BBC07: copied 1 file(s)
#   BBC10: no compiled files, skipping.
#   BBC16: no compiled files, skipping.
#   BBC17: copied 3 file(s)
#   BBC22: no compiled files, skipping.
#   BBC24: no compiled files, skipping.
#   BBC26: no compiled files, skipping.
#   BBC27: copied 17 file(s)
#   BBC31: no compiled files, skipping.
#   BBC33: copied 8 file(s)
#   BBC35: no compiled files, skipping.
#   BBC36: copied 10 file(s)
#   BBC41: no compiled files, skipping.
#   BBC42: no compiled files, skipping.
#   BBC44: no compiled files, skipping.
#   BBC45: copied 1 file(s)
#   BBC48: no compiled files, skipping.
#   BBC49: copied 6 file(s)
#   BBC50: no compiled files, skipping.
#   BBC51: no compiled files, skipping.
#   BBC52: no compiled files, skipping.
# ...

# %% [markdown]
# Execution Dataset

# %%
import json
import shutil
from pathlib import Path

# =============================================================================
# CONFIGURATION — only edit this section
# =============================================================================

# Folder containing BBC_instance/*.txt test files
TESTS_DIR = "/Volumes/Rachna-HD/FilteredDataset/Exp7LLMOutput/GPT4o"

# Full path to the compilation results JSON
JSON_PATH = "/Volumes/Rachna-HD/GPTResults/Exp7BatchResultsOp2/pre/execute_results_pre.json"

# Root folder where compiled_pre structure will be created
OUTPUT_DIR = "/Volumes/Rachna-HD/ResultsDataset/Exp7LLMOutput/GPT4o/execution_pre"

# =============================================================================


def diagnose(tests_base, results):
    """
    Before copying, inspect every compiled file in the JSON and report:
    - exact path we looked for on disk
    - what .txt files actually exist in that BBC instance folder
    """
    print("\n" + "="*60)
    print("DIAGNOSTIC RUN — no files will be copied")
    print("="*60)

    total_in_json = 0
    total_found   = 0
    total_missing = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("passed", [])
        if not compiled_files:
            continue

        src_instance_dir = tests_base / bbc_instance
        missing_in_instance = []

        for filename in compiled_files:
            total_in_json += 1
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                total_found += 1
            else:
                total_missing += 1
                missing_in_instance.append(stem)

        if missing_in_instance:
            print(f"\n[{bbc_instance}] {len(missing_in_instance)} missing:")
            for stem in missing_in_instance:
                print(f"  Looked for : {src_instance_dir / (stem + '_prompt.txt')}")

            # Show what .txt files actually exist in that folder
            actual_files = sorted(src_instance_dir.glob("*.txt")) if src_instance_dir.exists() else []
            if actual_files:
                print(f"  Actual .txt files in folder ({len(actual_files)}):")
                for f in actual_files:
                    print(f"    {f.name}")
            else:
                print(f"  Folder does not exist or has no .txt files: {src_instance_dir}")

    print("\n" + "="*60)
    print(f"Total in JSON  : {total_in_json}")
    print(f"Found on disk  : {total_found}")
    print(f"Missing        : {total_missing}")
    print("="*60 + "\n")


def organize_compiled_pre(run_diagnostic=False):
    tests_base  = Path(TESTS_DIR)
    json_path   = Path(JSON_PATH)
    output_base = Path(OUTPUT_DIR)

    if not json_path.exists():
        print(f"[ERROR] JSON file not found: {json_path}")
        return

    with open(json_path, "r") as f:
        data = json.load(f)

    results = data.get("execution_results", {})
    if not results:
        print("[ERROR] 'execution_results' key is empty or missing in JSON.")
        return

    if run_diagnostic:
        diagnose(tests_base, results)
        return

    copied_total  = 0
    missing_total = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("passed", [])

        if not compiled_files:
            print(f"  {bbc_instance}: no execution files, skipping.")
            continue

        src_instance_dir = tests_base / bbc_instance
        tgt_instance_dir = output_base / bbc_instance
        tgt_instance_dir.mkdir(parents=True, exist_ok=True)

        copied  = 0
        missing = 0
        for filename in compiled_files:
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"
            tgt_file = tgt_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                shutil.copy2(src_file, tgt_file)
                copied += 1
            else:
                print(f"    [MISSING] {src_file}")
                missing += 1

        print(f"  {bbc_instance}: copied {copied} file(s)"
              + (f", {missing} missing" if missing else ""))
        copied_total  += copied
        missing_total += missing

    print(f"\nDone. Total copied: {copied_total}, Total missing: {missing_total}")


if __name__ == "__main__":
    # Set to True to inspect mismatches before copying
    organize_compiled_pre(run_diagnostic=False)
# Out:
#   BBC03: copied 1 file(s)
#   BBC04: copied 1 file(s)
#   BBC06: copied 16 file(s)
#   BBC07: copied 2 file(s)
#   BBC17: copied 14 file(s)
#   BBC26: no execution files, skipping.
#   BBC27: copied 127 file(s)
#   BBC33: copied 55 file(s)
#   BBC36: copied 10 file(s)
#   BBC42: copied 1 file(s)
#   BBC45: copied 5 file(s)
#   BBC49: copied 18 file(s)
#   BBC50: copied 1 file(s)
#   BBC54: copied 55 file(s)
#   BBC56: copied 54 file(s)
#   BBC63: copied 4 file(s)
#   BBC66: no execution files, skipping.
#   BBC72: copied 106 file(s)
#   BBC73: copied 97 file(s)
#   BBC98: no execution files, skipping.
#   BBC101: copied 171 file(s)
#   BBC103: copied 4 file(s)
#   BBC106: copied 2 file(s)
#   BBC115: no execution files, skipping.
#   BBC123: no execution files, skipping.
#   BBC131: copied 4 file(s)
#   BBC132: copied 12 file(s)
#   BBC135: no execution files, skipping.
#   BBC136: copied 3 file(s)
#   BBC137: copied 1 file(s)
#   BBC145: copied 3 file(s)
# ...

# %%
import json
import shutil
from pathlib import Path

# =============================================================================
# CONFIGURATION — only edit this section
# =============================================================================

# Folder containing BBC_instance/*.txt test files
TESTS_DIR = "/Volumes/Rachna-HD/FilteredDataset/Exp7LLMOutput/Qwen3_480b_cloud"

# Full path to the compilation results JSON
JSON_PATH = "/Volumes/Rachna-HD/Qwen480Results/Exp7BatchResults/pre/execute_results_pre.json"

# Root folder where compiled_pre structure will be created
OUTPUT_DIR = "/Volumes/Rachna-HD/ResultsDataset/Exp7LLMOutput/Qwen3_480b_cloud/execution_pre"

# =============================================================================


def diagnose(tests_base, results):
    """
    Before copying, inspect every compiled file in the JSON and report:
    - exact path we looked for on disk
    - what .txt files actually exist in that BBC instance folder
    """
    print("\n" + "="*60)
    print("DIAGNOSTIC RUN — no files will be copied")
    print("="*60)

    total_in_json = 0
    total_found   = 0
    total_missing = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("passed", [])
        if not compiled_files:
            continue

        src_instance_dir = tests_base / bbc_instance
        missing_in_instance = []

        for filename in compiled_files:
            total_in_json += 1
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                total_found += 1
            else:
                total_missing += 1
                missing_in_instance.append(stem)

        if missing_in_instance:
            print(f"\n[{bbc_instance}] {len(missing_in_instance)} missing:")
            for stem in missing_in_instance:
                print(f"  Looked for : {src_instance_dir / (stem + '_prompt.txt')}")

            # Show what .txt files actually exist in that folder
            actual_files = sorted(src_instance_dir.glob("*.txt")) if src_instance_dir.exists() else []
            if actual_files:
                print(f"  Actual .txt files in folder ({len(actual_files)}):")
                for f in actual_files:
                    print(f"    {f.name}")
            else:
                print(f"  Folder does not exist or has no .txt files: {src_instance_dir}")

    print("\n" + "="*60)
    print(f"Total in JSON  : {total_in_json}")
    print(f"Found on disk  : {total_found}")
    print(f"Missing        : {total_missing}")
    print("="*60 + "\n")


def organize_compiled_pre(run_diagnostic=False):
    tests_base  = Path(TESTS_DIR)
    json_path   = Path(JSON_PATH)
    output_base = Path(OUTPUT_DIR)

    if not json_path.exists():
        print(f"[ERROR] JSON file not found: {json_path}")
        return

    with open(json_path, "r") as f:
        data = json.load(f)

    results = data.get("execution_results", {})
    if not results:
        print("[ERROR] 'execution_results' key is empty or missing in JSON.")
        return

    if run_diagnostic:
        diagnose(tests_base, results)
        return

    copied_total  = 0
    missing_total = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("passed", [])

        if not compiled_files:
            print(f"  {bbc_instance}: no execution files, skipping.")
            continue

        src_instance_dir = tests_base / bbc_instance
        tgt_instance_dir = output_base / bbc_instance
        tgt_instance_dir.mkdir(parents=True, exist_ok=True)

        copied  = 0
        missing = 0
        for filename in compiled_files:
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"
            tgt_file = tgt_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                shutil.copy2(src_file, tgt_file)
                copied += 1
            else:
                print(f"    [MISSING] {src_file}")
                missing += 1

        print(f"  {bbc_instance}: copied {copied} file(s)"
              + (f", {missing} missing" if missing else ""))
        copied_total  += copied
        missing_total += missing

    print(f"\nDone. Total copied: {copied_total}, Total missing: {missing_total}")


if __name__ == "__main__":
    # Set to True to inspect mismatches before copying
    organize_compiled_pre(run_diagnostic=False)
# Out:
#   BBC02: no execution files, skipping.
#   BBC03: no execution files, skipping.
#   BBC04: copied 5 file(s)
#   BBC06: copied 99 file(s)
#   BBC07: copied 2 file(s)
#   BBC17: copied 106 file(s)
#   BBC26: copied 1 file(s)
#   BBC27: copied 61 file(s)
#   BBC33: copied 55 file(s)
#   BBC36: copied 102 file(s)
#   BBC42: copied 2 file(s)
#   BBC45: copied 4 file(s)
#   BBC49: copied 97 file(s)
#   BBC50: copied 1 file(s)
#   BBC54: copied 60 file(s)
#   BBC56: copied 62 file(s)
#   BBC63: copied 4 file(s)
#   BBC72: copied 50 file(s)
#   BBC73: copied 48 file(s)
#   BBC101: copied 168 file(s)
#   BBC103: copied 3 file(s)
#   BBC106: copied 2 file(s)
#   BBC115: copied 4 file(s)
#   BBC123: no execution files, skipping.
#   BBC131: copied 6 file(s)
#   BBC132: copied 100 file(s)
#   BBC135: copied 1 file(s)
#   BBC136: copied 4 file(s)
#   BBC137: copied 1 file(s)
#   BBC143: copied 1 file(s)
#   BBC145: copied 1 file(s)
#   BBC146: copied 62 file(s)
#   BBC147: copied 62 file(s)
# ...

# %%
import json
import shutil
from pathlib import Path

# =============================================================================
# CONFIGURATION — only edit this section
# =============================================================================

# Folder containing BBC_instance/*.txt test files
TESTS_DIR = "/Volumes/Rachna-HD/FilteredDataset/Exp7LLMOutput/GPT_OSS_120b"

# Full path to the compilation results JSON
JSON_PATH = "/Volumes/Rachna-HD/GPTOSSResults/Exp7BatchResults/pre/execute_results_pre.json"

# Root folder where compiled_pre structure will be created
OUTPUT_DIR = "/Volumes/Rachna-HD/ResultsDataset/Exp7LLMOutput/GPT_OSS_120b/execution_pre"

# =============================================================================


def diagnose(tests_base, results):
    """
    Before copying, inspect every compiled file in the JSON and report:
    - exact path we looked for on disk
    - what .txt files actually exist in that BBC instance folder
    """
    print("\n" + "="*60)
    print("DIAGNOSTIC RUN — no files will be copied")
    print("="*60)

    total_in_json = 0
    total_found   = 0
    total_missing = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("passed", [])
        if not compiled_files:
            continue

        src_instance_dir = tests_base / bbc_instance
        missing_in_instance = []

        for filename in compiled_files:
            total_in_json += 1
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                total_found += 1
            else:
                total_missing += 1
                missing_in_instance.append(stem)

        if missing_in_instance:
            print(f"\n[{bbc_instance}] {len(missing_in_instance)} missing:")
            for stem in missing_in_instance:
                print(f"  Looked for : {src_instance_dir / (stem + '_prompt.txt')}")

            # Show what .txt files actually exist in that folder
            actual_files = sorted(src_instance_dir.glob("*.txt")) if src_instance_dir.exists() else []
            if actual_files:
                print(f"  Actual .txt files in folder ({len(actual_files)}):")
                for f in actual_files:
                    print(f"    {f.name}")
            else:
                print(f"  Folder does not exist or has no .txt files: {src_instance_dir}")

    print("\n" + "="*60)
    print(f"Total in JSON  : {total_in_json}")
    print(f"Found on disk  : {total_found}")
    print(f"Missing        : {total_missing}")
    print("="*60 + "\n")


def organize_compiled_pre(run_diagnostic=False):
    tests_base  = Path(TESTS_DIR)
    json_path   = Path(JSON_PATH)
    output_base = Path(OUTPUT_DIR)

    if not json_path.exists():
        print(f"[ERROR] JSON file not found: {json_path}")
        return

    with open(json_path, "r") as f:
        data = json.load(f)

    results = data.get("execution_results", {})
    if not results:
        print("[ERROR] 'execution_results' key is empty or missing in JSON.")
        return

    if run_diagnostic:
        diagnose(tests_base, results)
        return

    copied_total  = 0
    missing_total = 0

    for bbc_instance, instance_data in results.items():
        compiled_files = instance_data.get("passed", [])

        if not compiled_files:
            print(f"  {bbc_instance}: no execution files, skipping.")
            continue

        src_instance_dir = tests_base / bbc_instance
        tgt_instance_dir = output_base / bbc_instance
        tgt_instance_dir.mkdir(parents=True, exist_ok=True)

        copied  = 0
        missing = 0
        for filename in compiled_files:
            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"
            tgt_file = tgt_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                shutil.copy2(src_file, tgt_file)
                copied += 1
            else:
                print(f"    [MISSING] {src_file}")
                missing += 1

        print(f"  {bbc_instance}: copied {copied} file(s)"
              + (f", {missing} missing" if missing else ""))
        copied_total  += copied
        missing_total += missing

    print(f"\nDone. Total copied: {copied_total}, Total missing: {missing_total}")


if __name__ == "__main__":
    # Set to True to inspect mismatches before copying
    organize_compiled_pre(run_diagnostic=False)
# Out:
#   BBC04: copied 2 file(s)
#   BBC06: copied 9 file(s)
#   BBC07: copied 1 file(s)
#   BBC17: copied 3 file(s)
#   BBC27: copied 16 file(s)
#   BBC33: copied 7 file(s)
#   BBC36: copied 10 file(s)
#   BBC45: no execution files, skipping.
#   BBC49: copied 5 file(s)
#   BBC54: copied 6 file(s)
#   BBC56: copied 8 file(s)
#   BBC63: copied 1 file(s)
#   BBC72: copied 16 file(s)
#   BBC73: copied 11 file(s)
#   BBC88: copied 1 file(s)
#   BBC101: copied 9 file(s)
#   BBC103: no execution files, skipping.
#   BBC131: copied 1 file(s)
#   BBC132: copied 6 file(s)
#   BBC136: copied 1 file(s)
#   BBC146: copied 23 file(s)
#   BBC147: copied 8 file(s)
#   BBC165: copied 7 file(s)
#   BBC167: no execution files, skipping.
#
# Done. Total copied: 151, Total missing: 0

# %% [markdown]
# Detected_bre set

# %%
import json
import shutil
from pathlib import Path

# =============================================================================
# CONFIGURATION — only edit this section
# =============================================================================

# Folder containing BBC_instance/*.txt test files
TESTS_DIR = "/Volumes/Rachna-HD/FilteredDataset/Exp7LLMOutput/GPT4o"

# Full path to the detected breaking change results JSON
JSON_PATH = "/Volumes/Rachna-HD/GPTResults/Exp7BatchResultsOp2/bre/transplant_results_breaking_single_module.json"

# Root folder where detected_bre structure will be created
OUTPUT_DIR = "/Volumes/Rachna-HD/ResultsDataset/Exp7LLMOutput/GPT4o/detected_bre"

# =============================================================================


def diagnose(tests_base, results):
    """
    Before copying, inspect breaking change test files and report what's found/missing.
    """
    print("\n" + "="*60)
    print("DIAGNOSTIC RUN — no files will be copied")
    print("="*60)

    total_breaking_changes = 0
    total_found   = 0
    total_missing = 0

    for bbc_instance, instance_data in results.items():
        tests_data = instance_data.get("tests", {})
        failed_tests = tests_data.get("failed", [])

        # Filter only breaking changes
        breaking_changes = [
            t for t in failed_tests
            if t.get("result_type") == "test_failure_breaking_change"
        ]

        if not breaking_changes:
            continue

        src_instance_dir = tests_base / bbc_instance
        missing_in_instance = []

        for test in breaking_changes:
            total_breaking_changes += 1
            filename = test.get("file", "")
            if not filename:
                print(f"  [WARNING] {bbc_instance}: test missing 'file' key: {test}")
                continue

            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                total_found += 1
            else:
                total_missing += 1
                missing_in_instance.append(stem)

        if missing_in_instance:
            print(f"\n[{bbc_instance}] {len(missing_in_instance)} missing:")
            for stem in missing_in_instance:
                print(f"  Looked for : {src_instance_dir / (stem + '_prompt.txt')}")

            actual_files = sorted(src_instance_dir.glob("*.txt")) if src_instance_dir.exists() else []
            if actual_files:
                print(f"  Actual .txt files in folder ({len(actual_files)}):")
                for f in actual_files[:10]:  # Show first 10
                    print(f"    {f.name}")
                if len(actual_files) > 10:
                    print(f"    ... and {len(actual_files) - 10} more")
            else:
                print(f"  Folder does not exist or has no .txt files: {src_instance_dir}")

    print("\n" + "="*60)
    print(f"Total breaking changes : {total_breaking_changes}")
    print(f"Found on disk          : {total_found}")
    print(f"Missing                : {total_missing}")
    print("="*60 + "\n")


def organize_detected_bre(run_diagnostic=False):
    tests_base  = Path(TESTS_DIR)
    json_path   = Path(JSON_PATH)
    output_base = Path(OUTPUT_DIR)

    if not json_path.exists():
        print(f"[ERROR] JSON file not found: {json_path}")
        return

    with open(json_path, "r") as f:
        data = json.load(f)

    results = data.get("results", {})
    if not results:
        print("[ERROR] 'results' key is empty or missing in JSON.")
        return

    if run_diagnostic:
        diagnose(tests_base, results)
        return

    copied_total  = 0
    missing_total = 0

    for bbc_instance, instance_data in results.items():
        tests_data = instance_data.get("tests", {})
        failed_tests = tests_data.get("failed", [])

        # Filter only breaking changes
        breaking_changes = [
            t for t in failed_tests
            if t.get("result_type") == "test_failure_breaking_change"
        ]

        if not breaking_changes:
            print(f"  {bbc_instance}: no breaking change tests, skipping.")
            continue

        src_instance_dir = tests_base / bbc_instance
        tgt_instance_dir = output_base / bbc_instance
        tgt_instance_dir.mkdir(parents=True, exist_ok=True)

        copied  = 0
        missing = 0
        for test in breaking_changes:
            filename = test.get("file", "")
            if not filename:
                print(f"    [WARNING] {bbc_instance}: test missing 'file' key")
                continue

            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"
            tgt_file = tgt_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                shutil.copy2(src_file, tgt_file)
                copied += 1
            else:
                print(f"    [MISSING] {src_file}")
                missing += 1

        print(f"  {bbc_instance}: copied {copied} file(s)"
              + (f", {missing} missing" if missing else ""))
        copied_total  += copied
        missing_total += missing

    print(f"\nDone. Total copied: {copied_total}, Total missing: {missing_total}")


if __name__ == "__main__":
    # Set to True to inspect before copying
    organize_detected_bre(run_diagnostic=False)
# Out:
#   BBC03: copied 1 file(s)
#   BBC04: no breaking change tests, skipping.
#   BBC06: copied 16 file(s)
#   BBC07: no breaking change tests, skipping.
#   BBC17: copied 14 file(s)
#   BBC27: copied 4 file(s)
#   BBC33: copied 1 file(s)
#   BBC36: copied 10 file(s)
#   BBC42: copied 1 file(s)
#   BBC45: copied 1 file(s)
#   BBC49: copied 18 file(s)
#   BBC50: copied 1 file(s)
#   BBC54: copied 1 file(s)
#   BBC56: no breaking change tests, skipping.
#   BBC63: copied 2 file(s)
#   BBC72: copied 106 file(s)
#   BBC73: copied 97 file(s)
#   BBC101: no breaking change tests, skipping.
#   BBC103: copied 2 file(s)
#   BBC106: no breaking change tests, skipping.
#   BBC131: copied 2 file(s)
#   BBC132: copied 12 file(s)
#   BBC136: copied 2 file(s)
#   BBC137: no breaking change tests, skipping.
#   BBC145: no breaking change tests, skipping.
#   BBC146: copied 4 file(s)
#   BBC147: no breaking change tests, skipping.
#   BBC150: copied 7 file(s)
#   BBC162: copied 2 file(s)
# ...

# %%
import json
import shutil
from pathlib import Path

# =============================================================================
# CONFIGURATION — only edit this section
# =============================================================================

# Folder containing BBC_instance/*.txt test files
TESTS_DIR = "/Volumes/Rachna-HD/FilteredDataset/Exp7LLMOutput/Qwen3_480b_cloud"

# Full path to the detected breaking change results JSON
JSON_PATH = "/Volumes/Rachna-HD/Qwen480Results/Exp7BatchResults/bre/transplant_results_breaking_single_module.json"

# Root folder where detected_bre structure will be created
OUTPUT_DIR = "/Volumes/Rachna-HD/ResultsDataset/Exp7LLMOutput/Qwen3_480b_cloud/detected_bre"

# =============================================================================


def diagnose(tests_base, results):
    """
    Before copying, inspect breaking change test files and report what's found/missing.
    """
    print("\n" + "="*60)
    print("DIAGNOSTIC RUN — no files will be copied")
    print("="*60)

    total_breaking_changes = 0
    total_found   = 0
    total_missing = 0

    for bbc_instance, instance_data in results.items():
        tests_data = instance_data.get("tests", {})
        failed_tests = tests_data.get("failed", [])

        # Filter only breaking changes
        breaking_changes = [
            t for t in failed_tests
            if t.get("result_type") == "test_failure_breaking_change"
        ]

        if not breaking_changes:
            continue

        src_instance_dir = tests_base / bbc_instance
        missing_in_instance = []

        for test in breaking_changes:
            total_breaking_changes += 1
            filename = test.get("file", "")
            if not filename:
                print(f"  [WARNING] {bbc_instance}: test missing 'file' key: {test}")
                continue

            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                total_found += 1
            else:
                total_missing += 1
                missing_in_instance.append(stem)

        if missing_in_instance:
            print(f"\n[{bbc_instance}] {len(missing_in_instance)} missing:")
            for stem in missing_in_instance:
                print(f"  Looked for : {src_instance_dir / (stem + '_prompt.txt')}")

            actual_files = sorted(src_instance_dir.glob("*.txt")) if src_instance_dir.exists() else []
            if actual_files:
                print(f"  Actual .txt files in folder ({len(actual_files)}):")
                for f in actual_files[:10]:  # Show first 10
                    print(f"    {f.name}")
                if len(actual_files) > 10:
                    print(f"    ... and {len(actual_files) - 10} more")
            else:
                print(f"  Folder does not exist or has no .txt files: {src_instance_dir}")

    print("\n" + "="*60)
    print(f"Total breaking changes : {total_breaking_changes}")
    print(f"Found on disk          : {total_found}")
    print(f"Missing                : {total_missing}")
    print("="*60 + "\n")


def organize_detected_bre(run_diagnostic=False):
    tests_base  = Path(TESTS_DIR)
    json_path   = Path(JSON_PATH)
    output_base = Path(OUTPUT_DIR)

    if not json_path.exists():
        print(f"[ERROR] JSON file not found: {json_path}")
        return

    with open(json_path, "r") as f:
        data = json.load(f)

    results = data.get("results", {})
    if not results:
        print("[ERROR] 'results' key is empty or missing in JSON.")
        return

    if run_diagnostic:
        diagnose(tests_base, results)
        return

    copied_total  = 0
    missing_total = 0

    for bbc_instance, instance_data in results.items():
        tests_data = instance_data.get("tests", {})
        failed_tests = tests_data.get("failed", [])

        # Filter only breaking changes
        breaking_changes = [
            t for t in failed_tests
            if t.get("result_type") == "test_failure_breaking_change"
        ]

        if not breaking_changes:
            print(f"  {bbc_instance}: no breaking change tests, skipping.")
            continue

        src_instance_dir = tests_base / bbc_instance
        tgt_instance_dir = output_base / bbc_instance
        tgt_instance_dir.mkdir(parents=True, exist_ok=True)

        copied  = 0
        missing = 0
        for test in breaking_changes:
            filename = test.get("file", "")
            if not filename:
                print(f"    [WARNING] {bbc_instance}: test missing 'file' key")
                continue

            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"
            tgt_file = tgt_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                shutil.copy2(src_file, tgt_file)
                copied += 1
            else:
                print(f"    [MISSING] {src_file}")
                missing += 1

        print(f"  {bbc_instance}: copied {copied} file(s)"
              + (f", {missing} missing" if missing else ""))
        copied_total  += copied
        missing_total += missing

    print(f"\nDone. Total copied: {copied_total}, Total missing: {missing_total}")


if __name__ == "__main__":
    # Set to True to inspect before copying
    organize_detected_bre(run_diagnostic=False)
# Out:
#   BBC04: no breaking change tests, skipping.
#   BBC06: copied 98 file(s)
#   BBC07: no breaking change tests, skipping.
#   BBC17: copied 103 file(s)
#   BBC26: no breaking change tests, skipping.
#   BBC27: no breaking change tests, skipping.
#   BBC33: copied 1 file(s)
#   BBC36: copied 99 file(s)
#   BBC42: copied 2 file(s)
#   BBC45: no breaking change tests, skipping.
#   BBC49: copied 96 file(s)
#   BBC50: copied 1 file(s)
#   BBC54: no breaking change tests, skipping.
#   BBC56: copied 1 file(s)
#   BBC63: no breaking change tests, skipping.
#   BBC72: copied 49 file(s)
#   BBC73: copied 47 file(s)
#   BBC101: no breaking change tests, skipping.
#   BBC103: no breaking change tests, skipping.
#   BBC106: no breaking change tests, skipping.
#   BBC115: no breaking change tests, skipping.
#   BBC131: copied 1 file(s)
#   BBC132: copied 98 file(s)
#   BBC135: no breaking change tests, skipping.
#   BBC136: no breaking change tests, skipping.
# ...

# %%
import json
import shutil
from pathlib import Path

# =============================================================================
# CONFIGURATION — only edit this section
# =============================================================================

# Folder containing BBC_instance/*.txt test files
TESTS_DIR = "/Volumes/Rachna-HD/FilteredDataset/Exp7LLMOutput/GPT_OSS_120b"

# Full path to the detected breaking change results JSON
JSON_PATH = "/Volumes/Rachna-HD/GPTOSSResults/Exp7BatchResults/bre/transplant_results_breaking_single_module.json"

# Root folder where detected_bre structure will be created
OUTPUT_DIR = "/Volumes/Rachna-HD/ResultsDataset/Exp7LLMOutput/GPT_OSS_120b/detected_bre"

# =============================================================================


def diagnose(tests_base, results):
    """
    Before copying, inspect breaking change test files and report what's found/missing.
    """
    print("\n" + "="*60)
    print("DIAGNOSTIC RUN — no files will be copied")
    print("="*60)

    total_breaking_changes = 0
    total_found   = 0
    total_missing = 0

    for bbc_instance, instance_data in results.items():
        tests_data = instance_data.get("tests", {})
        failed_tests = tests_data.get("failed", [])

        # Filter only breaking changes
        breaking_changes = [
            t for t in failed_tests
            if t.get("result_type") == "test_failure_breaking_change"
        ]

        if not breaking_changes:
            continue

        src_instance_dir = tests_base / bbc_instance
        missing_in_instance = []

        for test in breaking_changes:
            total_breaking_changes += 1
            filename = test.get("file", "")
            if not filename:
                print(f"  [WARNING] {bbc_instance}: test missing 'file' key: {test}")
                continue

            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                total_found += 1
            else:
                total_missing += 1
                missing_in_instance.append(stem)

        if missing_in_instance:
            print(f"\n[{bbc_instance}] {len(missing_in_instance)} missing:")
            for stem in missing_in_instance:
                print(f"  Looked for : {src_instance_dir / (stem + '_prompt.txt')}")

            actual_files = sorted(src_instance_dir.glob("*.txt")) if src_instance_dir.exists() else []
            if actual_files:
                print(f"  Actual .txt files in folder ({len(actual_files)}):")
                for f in actual_files[:10]:  # Show first 10
                    print(f"    {f.name}")
                if len(actual_files) > 10:
                    print(f"    ... and {len(actual_files) - 10} more")
            else:
                print(f"  Folder does not exist or has no .txt files: {src_instance_dir}")

    print("\n" + "="*60)
    print(f"Total breaking changes : {total_breaking_changes}")
    print(f"Found on disk          : {total_found}")
    print(f"Missing                : {total_missing}")
    print("="*60 + "\n")


def organize_detected_bre(run_diagnostic=False):
    tests_base  = Path(TESTS_DIR)
    json_path   = Path(JSON_PATH)
    output_base = Path(OUTPUT_DIR)

    if not json_path.exists():
        print(f"[ERROR] JSON file not found: {json_path}")
        return

    with open(json_path, "r") as f:
        data = json.load(f)

    results = data.get("results", {})
    if not results:
        print("[ERROR] 'results' key is empty or missing in JSON.")
        return

    if run_diagnostic:
        diagnose(tests_base, results)
        return

    copied_total  = 0
    missing_total = 0

    for bbc_instance, instance_data in results.items():
        tests_data = instance_data.get("tests", {})
        failed_tests = tests_data.get("failed", [])

        # Filter only breaking changes
        breaking_changes = [
            t for t in failed_tests
            if t.get("result_type") == "test_failure_breaking_change"
        ]

        if not breaking_changes:
            print(f"  {bbc_instance}: no breaking change tests, skipping.")
            continue

        src_instance_dir = tests_base / bbc_instance
        tgt_instance_dir = output_base / bbc_instance
        tgt_instance_dir.mkdir(parents=True, exist_ok=True)

        copied  = 0
        missing = 0
        for test in breaking_changes:
            filename = test.get("file", "")
            if not filename:
                print(f"    [WARNING] {bbc_instance}: test missing 'file' key")
                continue

            stem     = Path(filename).stem
            src_file = src_instance_dir / f"{stem}_prompt.txt"
            tgt_file = tgt_instance_dir / f"{stem}_prompt.txt"

            if src_file.exists():
                shutil.copy2(src_file, tgt_file)
                copied += 1
            else:
                print(f"    [MISSING] {src_file}")
                missing += 1

        print(f"  {bbc_instance}: copied {copied} file(s)"
              + (f", {missing} missing" if missing else ""))
        copied_total  += copied
        missing_total += missing

    print(f"\nDone. Total copied: {copied_total}, Total missing: {missing_total}")


if __name__ == "__main__":
    # Set to True to inspect before copying
    organize_detected_bre(run_diagnostic=False)
# Out:
#   BBC04: no breaking change tests, skipping.
#   BBC06: copied 9 file(s)
#   BBC07: no breaking change tests, skipping.
#   BBC17: copied 3 file(s)
#   BBC27: no breaking change tests, skipping.
#   BBC33: no breaking change tests, skipping.
#   BBC36: copied 10 file(s)
#   BBC49: copied 4 file(s)
#   BBC54: no breaking change tests, skipping.
#   BBC56: no breaking change tests, skipping.
#   BBC63: no breaking change tests, skipping.
#   BBC72: copied 16 file(s)
#   BBC73: copied 11 file(s)
#   BBC88: no breaking change tests, skipping.
#   BBC101: no breaking change tests, skipping.
#   BBC131: no breaking change tests, skipping.
#   BBC132: copied 6 file(s)
#   BBC136: no breaking change tests, skipping.
#   BBC146: copied 1 file(s)
#   BBC147: no breaking change tests, skipping.
#   BBC165: copied 7 file(s)
#
# Done. Total copied: 67, Total missing: 0
